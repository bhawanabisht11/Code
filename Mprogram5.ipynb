# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y)

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='green',linewidth=3,linestyle='dotted')

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y, 'g+')

# %%
plt.plot(x,y, 'g+--')

# %%
plt.plot(x,y, 'rD--')

# %%
plt.plot(x,y, 'rD')

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(x,y,color='red',marker='D',linestyle='')

# %%
plt.plot(x,y,color='#008040',marker='D',linestyle='')

# %%
plt.plot(x,y, color='red', marker='+', linestyle='', markersize=20)

# %%
plt.plot(x,y, color='green', alpha=1)

# %% [markdown]
# # add transparency to a color alpha

# %%
plt.plot(x,y, color='green', alpha=0.5)

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

# %%
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(days, max_t)

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,50,51,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(days,max_t)
plt.plot(days,min_t)
plt.plot(days,avg_t)

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(days,max_t, label='Max')
plt.plot(days,min_t, label='Min')
plt.plot(days,avg_t, label= 'Avg')

plt.legend()

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(days,max_t, label='Max')
plt.plot(days,min_t, label='Min')
plt.plot(days,avg_t, label= 'Avg')

plt.legend(loc="best", shadow=True)

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(days,max_t, label='Max')
plt.plot(days,min_t, label='Min')
plt.plot(days,avg_t, label= 'Avg')

plt.legend(loc="best", shadow=True, fontsize='large')

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,50,48,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

# %%
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(days,max_t, label='Max')
plt.plot(days,min_t, label='Min')
plt.plot(days,avg_t, label= 'Avg')

plt.legend(loc="best", shadow=True, fontsize='large')

plt.grid()
